# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Loan_default.csv')
df.head()
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# ...

# %%
df.shape
# Out:
# (255347, 18)

# %%
df.isna().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
df['NumCreditLines'] = df['NumCreditLines'].astype(object)
df['LoanTerm'] = df['LoanTerm'].astype(object)

# %%
df['Education'].value_counts()
# Out:
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: Education, dtype: int64

# %%
df['EmploymentType'].value_counts()
# Out:
# Part-time        64161
# Unemployed       63824
# Self-employed    63706
# Full-time        63656
# Name: EmploymentType, dtype: int64

# %%
df.drop('Default', axis=1).describe().round(decimals=2)
# Out:
#              Age     Income  LoanAmount  CreditScore  MonthsEmployed  \
# count  255347.00  255347.00   255347.00    255347.00       255347.00
# mean       43.50   82499.30   127578.87       574.26           59.54
# std        14.99   38963.01    70840.71       158.90           34.64
# min        18.00   15000.00     5000.00       300.00            0.00
# 25%        31.00   48825.50    66156.00       437.00           30.00
# 50%        43.00   82466.00   127556.00       574.00           60.00
# 75%        56.00  116219.00   188985.00       712.00           90.00
# max        69.00  149999.00   249999.00       849.00          119.00
#
#        InterestRate   DTIRatio
# count     255347.00  255347.00
# mean          13.49       0.50
# std            6.64       0.23
# min            2.00       0.10
# 25%            7.77       0.30
# 50%           13.46       0.50
# 75%           19.25       0.70
# max           25.00       0.90

# %%
fig = plt.figure(figsize=(10,6))
sns.heatmap(df.drop('Default', axis=1).corr(), 
            cmap='RdBu_r', 
            vmin=-1, vmax=1, 
            annot=True);

# %%
sns.set()
sns.distplot(df['LoanAmount'],bins=10,color='gray');

# %%
sns.set()
sns.distplot(df['Income'],bins=9,color='gray');

# %%
sns.set()
sns.distplot(df['LoanAmount'],bins=5,color='gray');

# %%
sns.set()
sns.distplot(df['MonthsEmployed'],bins=5,color='gray');

# %%
sns.set()
sns.distplot(df['InterestRate'],bins=5,color='gray');

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2);

sns.set()
ax1.hist(df['Income'],bins=9,color='gray')
ax2.hist(df['LoanAmount'],bins=5,color='gray')
ax3.hist(df['MonthsEmployed'],bins=5,color='gray')
ax4.hist(df['InterestRate'],bins=5,color='gray');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  object
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  object
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
feat_quali = ['LoanID','NumCreditLines','LoanTerm','Education','EmploymentType', 'MaritalStatus', 'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner']

# %%
df2 = df.drop(feat_quali, axis=1)
sns.pairplot(df2, hue='Default');

# %%
sns.pairplot(df[['Age','Default']], hue='Default', aspect=2, palette='rocket',corner='true')
plt.legend(fontsize='small', loc ='upper right', framealpha=0.5)
plt.title('Age data distribution by Default',fontsize=12);

# %%
sns.pairplot(df[['Income','Default']], hue='Default', aspect=2, palette='rocket', corner='true')
plt.legend(fontsize='small', loc ='upper right', framealpha=0.5)
plt.title('Income data distribution by Default',fontsize=12);

# %%
sns.pairplot(df[['InterestRate','Default']], hue='Default', aspect=2, palette= 'rocket', corner='true')
plt.legend(fontsize='small', loc ='upper left', framealpha=0.5)
plt.title('Interest Rate data distribution by Default',fontsize=12);

# %%
sns.pairplot(df[['MonthsEmployed','Default']], hue='Default', aspect=2, palette= 'rocket', corner='true')
plt.legend(fontsize='small', loc ='upper left', framealpha=0.5)
plt.title('Months Emlployed data distribution by Default',fontsize=12);

# %%
sns.pairplot(df[['LoanAmount','Default']], hue='Default', aspect=2, palette = 'rocket', corner='true')
plt.legend(fontsize='small', loc ='upper left', framealpha=0.5)
plt.title('Loan Amount data distribution by Default',fontsize=12);

# %%
sns.pairplot(df[['CreditScore','Default']], hue='Default', aspect=2, palette = 'rocket', corner='true')
plt.legend(fontsize='small', loc ='upper left', framealpha=0.5)
plt.title('Credit Score data distribution by Default',fontsize=12);

# %%
sns.pairplot(df[['DTIRatio','Default']], hue='Default', aspect=2, palette = 'rocket', corner='true')
plt.legend(fontsize='small', loc ='upper left', framealpha=0.5)
plt.title('DTI Ratio data distribution by Default',fontsize=12);

# %%
# Nomes de paletas padrão: "deep", "muted", "bright", "pastel", "dark", "colorblind"

# Paletas de cores seaborn:"magma", "viridis", "cubehelix", "rocket"
