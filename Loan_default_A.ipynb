# %%
# Testing different models:

# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split

import imblearn as mb
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# %%
from sklearn.ensemble import GradientBoostingClassifier
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import sys
import math
from hyperopt import space_eval

# %%
from sklearn.preprocessing import StandardScaler

# Pacotes para Redes Neurais Artificiais
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
from scikeras.wrappers import KerasRegressor

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from scipy import stats
from scipy.stats import ks_2samp
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
df = pd.read_csv('Loan_default.csv')
df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                    4         15.23        36      0.44   Bachelor's
# 1                    1          4.81        60      0.68     Master's
# 2                    3         21.17        24      0.31     Master's
# 3                    3          7.07        24      0.23  High School
# 4                    4          6.51        48      0.73   Bachelor's
# ...                ...           ...       ...       ...          ...
# 255342               4         14.11        12      0.85   Bachelor's
# 255343               2         11.55        24      0.21  High School
# 255344               3          5.29        60      0.50  High School
# 255345               1         20.90        48      0.44  High School
# 255346               2          6.73        12      0.48   Bachelor's
#
#        EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0           Full-time      Divorced         Yes           Yes       Other
# 1           Full-time       Married          No            No       Other
# 2          Unemployed      Divorced         Yes           Yes        Auto
# 3           Full-time       Married          No            No    Business
# 4          Unemployed      Divorced          No           Yes        Auto
# ...               ...           ...         ...           ...         ...
# 255342      Full-time       Married          No            No       Other
# 255343      Part-time      Divorced          No            No        Home
# 255344  Self-employed       Married         Yes           Yes        Auto
# 255345      Part-time        Single         Yes           Yes       Other
# 255346     Unemployed      Divorced         Yes            No   Education
#
#        HasCoSigner  Default
# 0              Yes        0
# 1              Yes        0
# 2               No        1
# 3               No        0
# 4               No        0
# ...            ...      ...
# 255342          No        0
# 255343          No        1
# 255344         Yes        0
# 255345          No        0
# 255346         Yes        0
#
# [255347 rows x 18 columns]

# %%
df['NumCreditLines'] = df['NumCreditLines'].astype(object)
df['LoanTerm'] = df['LoanTerm'].astype(object)

# %%
y = df['Default']

x_feat_name = ['Age','InterestRate','Income','MonthsEmployed','LoanAmount']

x = df[x_feat_name]

# %%
# Division into training and testing:    
X_train, X_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.30,
                                                    random_state=42)

# %%
# Division into train and validation:    
x_train2, x_valid, y_train2, y_valid = train_test_split(x_train, y_train, 
                                                        test_size=0.20,
                                                        random_state=42)

# %%
# Applying tomek, under e oversampling to increase the minority class proportion.
# Note: The use of both under and oversampling aimed to avoid obtaining a very large base.

under_tomek = TomekLinks(sampling_strategy='majority',n_jobs=4)

x_train_tomek, y_train_tomek = under_tomek.fit_resample(x_train2, y_train2)

rnd_under = RandomUnderSampler(sampling_strategy=0.35,
                                        random_state=42)
x_train_under, y_train_under = rnd_under.fit_resample(x_train_tomek, y_train_tomek)

smote = SMOTE(sampling_strategy= 1, random_state=42)

x_train_over, y_train_over = smote.fit_resample(x_train_under, y_train_under)

# %%
y_train_over.mean()
# Out:
# 0.5

# %%
# Note: Different proportions of minority class were tested.
#       The best proportion was 50 % of the nimority class (target).

# %%
# Gradient Boosting Classifier:

# %%
# Defining the function structure of the prediction model:

def train_oversm_boosting (estimators, lean_rate, sample, max_dp): 
    

    model_gbc = GradientBoostingClassifier(n_estimators = estimators, 
                                           learning_rate = lean_rate,
                                           min_samples_leaf = 100,
                                           subsample = sample,           
                                           max_depth = max_dp,
                                           validation_fraction=0.4,
                                           random_state = 42)
                                            
    return model_gbc

# %%
# Definition of hyperparametric space:

est = np.arange(50, 110, 10) 

leanrt = np.arange(0.30, 1.0, 0.10).round(decimals=2) 

samp = np.arange(0.30, 1.0, 0.20).round(decimals=2) 
 
maxdp = np.arange(3, 20, 1) 

# Defining the dictionary of hyperparameters: 
param_grid = dict(estimators=est,
                  lean_rate=leanrt,
                  sample =samp,
                  max_dp = maxdp)

# %%
bo_space = {'estimators': hp.choice('estimators', param_grid['estimators']),
            'lean_rate': hp.choice('lean_rate', param_grid['lean_rate']),
            'sample': hp.choice('sample', param_grid['sample']),
            'max_dp': hp.choice('max_dp', param_grid['max_dp'])}

# %%
# Defining the function that will be optimized:
   
# The metrics used to find the best hyperparameters were the Precision and the Recall.
# The objective was to obtain the highest possible values for both metrics and at the same time
# obtain a minimum variation between training and test performances. 
# Hypothetical points were considered in a 2D space, where x would be the value of the metric and y 
# would be the difference between trainig and testing performance values. 
# Considering this, the ideal point in this 2D space would be the point (1,0).
# Therefore, the distance between the real point and the ideal point should be as small as possible.
# The distance between 2 points in a 2D space is called The Euclidean distance.
# The sum of the Euclidean distances of the precision and recall metrics was used as the loss of the optimization.

# %%
def bo_gpc(param):   

    print ('tested_hyperparameters: ', param)
    model_bo= train_oversm_boosting(estimators=param['estimators'], 
                                    lean_rate=param['lean_rate'],
                                    sample =param['sample'],
                                    max_dp=param['max_dp'])   
    
    model_bo.fit(x_train_over, y_train_over)    
      
    ypred_train = model_bo.predict(x_train_over)
    
    ypred_valid = model_bo.predict(x_valid)
    
    Prec_train = precision_score(y_train_over, ypred_train)    
    Prec_valid = precision_score(y_valid, ypred_valid)    
    Prec_Diference = (Prec_train - Prec_valid)/Prec_train
        
    Recl_train = recall_score(y_train_over, ypred_train)    
    Recl_valid = recall_score(y_valid, ypred_valid)    
    Recl_Diference = (Recl_train - Recl_valid)/Recl_train
    
    D_p = math.sqrt((Prec_valid - 1)**2 + (Prec_Diference - 0)**2)
    D_r = math.sqrt((Recl_valid - 1)**2 + (Recl_Diference - 0)**2)
    D_t = D_p + D_r
    
    print('Recl_valid :', Recl_valid, 'Recl_train :', Recl_train,
         'Prec_valid :', Prec_valid, 'Prec_train :',Prec_train)
    
    return {'loss': D_t,'status': STATUS_OK}

# %%
trials = Trials()                  
bo_search = fmin(fn= bo_gpc,       
                 space= bo_space,  
                 algo=tpe.suggest, 
                 max_evals=10,     
                 trials=trials)
# Out:
# tested_hyperparameters:
# {'estimators': 70, 'lean_rate': 0.7, 'max_dp': 6, 'sample': 0.9}
# Prec_valid :
# 0.19725072099577495
# Diference_Prec :
# 0.7325079436942346
# Recl_valid :
# 0.6104492070779631
# Diference_Recl :
# 0.21523423648700854
# tested_hyperparameters:
# {'estimators': 70, 'lean_rate': 0.5, 'max_dp': 18, 'sample': 0.5}
#  10%|████▌                                         | 1/10 [06:46<1:00:59, 406.63s/trial, best loss: 1.5317832578011592]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [153], in <cell line: 2>()
#       1 trials = Trials()
# ----> 2 bo_search = fmin(fn= bo_gpc,
#       3                  space= bo_space,
#       4                  algo=tpe.suggest,
#       5                  max_evals=10,
#       6                  trials=trials)
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\fmin.py:469, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     466 validate_loss_threshold(loss_threshold)
#     468 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 469     return trials.fmin(
#     470         fn,
#     471         space,
#     472         algo=algo,
#     473         max_evals=max_evals,
#     474         timeout=timeout,
#     475         loss_threshold=loss_threshold,
#     476         max_queue_len=max_queue_len,
#     477         rstate=rstate,
#     478         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     479         verbose=verbose,
#     480         catch_eval_exceptions=catch_eval_exceptions,
#     481         return_argmin=return_argmin,
#     482         show_progressbar=show_progressbar,
#     483     )
#     485 if trials is None:
#     486     if points_to_evaluate is None:
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo,
#     675     max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687 )
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\fmin.py:509, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     506 rval.catch_eval_exceptions = catch_eval_exceptions
#     508 # next line is where the fmin is actually executed
# --> 509 rval.exhaust()
#     511 if return_argmin:
#     512     if len(trials.trials) == 0:
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\fmin.py:330, in FMinIter.exhaust(self)
#     328 def exhaust(self):
#     329     n_done = len(self.trials)
# --> 330     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     331     self.trials.refresh()
#     332     return self
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\fmin.py:286, in FMinIter.run(self, N, block_until_done)
#     283     time.sleep(self.poll_interval_secs)
#     284 else:
#     285     # -- loop over trials and do the jobs directly
# --> 286     self.serial_evaluate()
#     288 self.trials.refresh()
#     290 # update progress bar with the min loss among trials with status ok
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\fmin.py:165, in FMinIter.serial_evaluate(self, N)
#     163 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     164 try:
# --> 165     result = self.domain.evaluate(spec, ctrl)
#     166 except Exception as e:
#     167     logger.error("job exception: %s" % str(e))
#
# File c:\users\kaka_\preditiva\lib\site-packages\hyperopt\base.py:894, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     885 else:
#     886     # -- the "work" of evaluating `config` can be written
#     887     #    either into the pyll part (self.expr)
#     888     #    or the normal Python part (self.fn)
#     889     pyll_rval = pyll.rec_eval(
#     890         self.expr,
#     891         memo=memo,
#     892         print_node_on_error=self.rec_eval_print_node_on_error,
#     893     )
# --> 894     rval = self.fn(pyll_rval)
#     896 if isinstance(rval, (float, int, np.number)):
#     897     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Input In [152], in bo_gpc(param)
#      29 smote = SMOTE(sampling_strategy= 1, random_state=42)
#      31 x_train_over, y_train_over = smote.fit_resample(x_train_under, y_train_under)
# ---> 33 model_bo.fit(x_train_over, y_train_over)
#      35 ypred_train = model_bo.predict(x_train_over)
#      36 y_proba_train = model_bo.predict_proba(x_train_over)[:,1]
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\ensemble\_gb.py:532, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     529     self._resize_state()
#     531 # fit the boosting stages
# --> 532 n_stages = self._fit_stages(
#     533     X_train,
#     534     y_train,
#     535     raw_predictions,
#     536     sample_weight_train,
#     537     self._rng,
#     538     X_val,
#     539     y_val,
#     540     sample_weight_val,
#     541     begin_at_stage,
#     542     monitor,
#     543 )
#     545 # change shape of arrays after fit (early-stopping or additional ests)
#     546 if n_stages != self.estimators_.shape[0]:
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\ensemble\_gb.py:610, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     603         initial_loss = loss_(
#     604             y[~sample_mask],
#     605             raw_predictions[~sample_mask],
#     606             sample_weight[~sample_mask],
#     607         )
#     609 # fit next stage of trees
# --> 610 raw_predictions = self._fit_stage(
#     611     i,
#     612     X,
#     613     y,
#     614     raw_predictions,
#     615     sample_weight,
#     616     sample_mask,
#     617     random_state,
#     618     X_csc,
#     619     X_csr,
#     620 )
#     622 # track loss
#     623 if do_oob:
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\ensemble\_gb.py:245, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     242     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     244 X = X_csr if X_csr is not None else X
# --> 245 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247 # update tree leaves
#     248 loss.update_terminal_regions(
#     249     tree.tree_,
#     250     X,
#    (...)
#     257     k=k,
#     258 )
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File c:\users\kaka_\preditiva\lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# Obtaining the best hyperparameters:

bo_better_hp = space_eval(bo_space, bo_search)
print('Better hyperparameters: ', bo_better_hp)
# Out:
# Better hyperparameters:  {'estimators': 100, 'lean_rate': 0.5, 'max_dp': 3, 'sample': 0.3}

# %%
# Fitting the chosen models (best hyperparameters):

# %%
model_gbc = train_oversm_boosting (estimators=100, lean_rate=0.5, sample=0.3, max_dp=3) 

model_gbc.fit(x_train_over, y_train_over)
# Out:
# GradientBoostingClassifier(learning_rate=0.5, min_samples_leaf=100,
#                            random_state=42, subsample=0.3,
#                            validation_fraction=0.4)

# %%
per_gbc = performances (model_gbc, x_train_over, y_train_over, X_test, y_test, 0.50) 
per_gbc
# Out:
#           Train  Test  Variation
# Recall     0.74  0.65      -0.12
# AUROC      0.78  0.72      -0.08
# KS         0.42  0.32      -0.24
# Accuracy   0.71  0.67      -0.06

# %%
# Bagging of Logistic regression:

# %%
def train_bagg_lr (estimators, samples, features): 
    
    model_base = LogisticRegression(max_iter=1000)   

    num_estimators = estimators          
  

    model_bagg_lr = BaggingClassifier(estimator = model_base, 
                                       n_estimators = num_estimators, 
                                       max_samples= samples,    
                                       max_features= features,   
                                       random_state = 42) 
    return model_bagg_lr

# %%
# Definition of the hyperparametric space:

est = np.arange(50, 210, 50)

samp = np.arange(0.30, 1, 0.20) 

feat = np.arange(0.60, 1.00, 0.39).round(decimals=2) 

param_grid = dict(estimators=est,
                 samples = samp,
                 features = feat)

# %%
bo_space2 = {'estimators': hp.choice('estimators', param_grid['estimators']),
            'samples': hp.choice('samples', param_grid['samples']),
            'features': hp.choice('features', param_grid['features'])}

# %%
# Defining the function that will be optimized:

# The metrics used to find the best hyperparameters were the Precision and the Recall.
# The objective was to obtain the highest possible values for both metrics and at the same time
# obtain a minimum variation between training and test performances. 
# Hypothetical points were considered in a 2D space, where x would be the value of the metric and y 
# would be the difference between trainig and testing performance values. 
# Considering this, the ideal point in this 2D space would be the point (1,0).
# Therefore, the distance between the real point and the ideal point should be as small as possible.
# The distance between 2 points in a 2D space is called The Euclidean distance.
# The sum of the Euclidean distances of the precision and recall metrics was used as the loss of the optimization.

# %%
def bo_bagg(param):   

    print ('tested_hyperparameters: ', param)
    model_bo = train_bagg_lr (estimators=param['estimators'],
                              samples=param['samples'], 
                              features=param['features'])
    
    model_bo.fit(x_train_over, y_train_over)    
      
    ypred_train = model_bo.predict(x_train_over)
    
    ypred_valid = model_bo.predict(x_valid)
    
    Prec_train = precision_score(y_train_over, ypred_train)    
    Prec_valid = precision_score(y_valid, ypred_valid)    
    Prec_Diference = (Prec_train - Prec_valid)/Prec_train
        
    Recl_train = recall_score(y_train_over, ypred_train)    
    Recl_valid = recall_score(y_valid, ypred_valid)    
    Recl_Diference = (Recl_train - Recl_valid)/Recl_train
    
    D_p = math.sqrt((Prec_valid - 1)**2 + (Prec_Diference - 0)**2)
    D_r = math.sqrt((Recl_valid - 1)**2 + (Recl_Diference - 0)**2)
    D_t = D_p + D_r
    
    print('Recl_valid :', Recl_valid, 'Recl_train :', Recl_train,
         'Prec_valid :', Prec_valid, 'Prec_train :',Prec_train)
    
    return {'loss': D_t,'status': STATUS_OK}

# %%
# Defining the parameters of the "fmin" optimization function:

# %%
trials = Trials()                  
bo_search2 = fmin(fn= bo_bagg,       
                 space= bo_space2,  
                 algo=tpe.suggest, 
                 max_evals=15,     
                 trials=trials)
# Out:
# tested_hyperparameters:
# {'estimators': 150, 'features': 0.6, 'samples': 0.5}
# Recl_valid :
# 0.5964233929434509
# Recl_train :
# 0.6015779924897684
# Prec_valid :
# 0.21013197105151127
# Prec_train :
# 0.6784839039710676
# tested_hyperparameters:
# {'estimators': 200, 'features': 0.99, 'samples': 0.5}
# Recl_valid :
# 0.6179313678105365
# Recl_train :
# 0.6314290536264293
# Prec_valid :
# 0.2083265439139645
# Prec_train :
# 0.6773098594736485
# tested_hyperparameters:
# {'estimators': 100, 'features': 0.99, 'samples': 0.7}
# Recl_valid :
# 0.6225229579507008
# Recl_train :
# 0.6391713429813088
# Prec_valid :
# 0.20968660968660968
# Prec_train :
# 0.6791446247646373
# tested_hyperparameters:
# {'estimators': 50, 'features': 0.99, 'samples': 0.3}
# Recl_valid :
# 0.6034316094731754
# Recl_train :
# 0.616450782667398
# Prec_valid :
# 0.2053285091686539
# Prec_train :
# 0.674304834429445
# tested_hyperparameters:
# {'estimators': 50, 'features': 0.6, 'samples': 0.9000000000000001}
# Recl_valid :
# 0.5850652489125181
# Recl_train :
# 0.5953757225433526
# Prec_valid :
# 0.21259220231822973
# Prec_train :
# 0.6824656010446642
# tested_hyperparameters:
# {'estimators': 150, 'features': 0.99, 'samples': 0.3}
# Recl_valid :
# 0.6210729821169647
# Recl_train :
# 0.6334964769419011
# Prec_valid :
# 0.20928338762214985
# Prec_train :
# 0.678330208498046
# tested_hyperparameters:
# {'estimators': 100, 'features': 0.99, 'samples': 0.3}
# Recl_valid :
# 0.6164813919768004
# Recl_train :
# 0.6293827264672377
# Prec_valid :
# 0.2087390557237542
# Prec_train :
# 0.6777835836154213
# tested_hyperparameters:
# {'estimators': 150, 'features': 0.6, 'samples': 0.3}
# Recl_valid :
# 0.6041565973900435
# Recl_train :
# 0.6098898780642167
# Prec_valid :
# 0.2115775220040623
# Prec_train :
# 0.6798993438536253
# tested_hyperparameters:
# {'estimators': 100, 'features': 0.6, 'samples': 0.3}
# Recl_valid :
# 0.5990816819719671
# Recl_train :
# 0.6128855322560229
# Prec_valid :
# 0.21534051424600417
# Prec_train :
# 0.6860300368376311
# tested_hyperparameters:
# {'estimators': 150, 'features': 0.6, 'samples': 0.3}
# Recl_valid :
# 0.6041565973900435
# Recl_train :
# 0.6098898780642167
# Prec_valid :
# 0.2115775220040623
# Prec_train :
# 0.6798993438536253
# tested_hyperparameters:
# {'estimators': 100, 'features': 0.6, 'samples': 0.7}
# Recl_valid :
# 0.5891735137747705
# Recl_train :
# 0.5980760305472342
# Prec_valid :
# 0.21384089114989913
# Prec_train :
# 0.6838245935645714
# tested_hyperparameters:
# {'estimators': 200, 'features': 0.99, 'samples': 0.7}
# Recl_valid :
# 0.6205896568390527
# Recl_train :
# 0.6349521117252437
# Prec_valid :
# 0.20932507336159112
# Prec_train :
# 0.6787389500270612
# tested_hyperparameters:
# {'estimators': 50, 'features': 0.6, 'samples': 0.5}
# Recl_valid :
# 0.5843402609956501
# Recl_train :
# 0.5940677608539724
# Prec_valid :
# 0.21171526136065144
# Prec_train :
# 0.6809663144149155
# tested_hyperparameters:
# {'estimators': 50, 'features': 0.6, 'samples': 0.7}
# Recl_valid :
# 0.5913484775253746
# Recl_train :
# 0.6023585502721405
# Prec_valid :
# 0.21167820069204152
# Prec_train :
# 0.6816836174378074
# tested_hyperparameters:
# {'estimators': 200, 'features': 0.99, 'samples': 0.3}
# Recl_valid :
# 0.6215563073948768
# Recl_train :
# 0.6349310155689634
# Prec_valid :
# 0.20912269290186195
# Prec_train :
# 0.6783186837953572
# 100%|█████████████████████████████████████████████████| 15/15 [07:55<00:00, 31.69s/trial, best loss: 1.428336706203769]

# %%
# Obtaining the best hyperparameters:

bo_better_hp2 = space_eval(bo_space2, bo_search2)
print('Better hyperparameters: ', bo_better_hp2)
# Out:
# Better hyperparameters:  {'estimators': 100, 'features': 0.99, 'samples': 0.7}

# %%
# Fitting the chosen models (best hyperparameters):

# %%
model_bagg = train_bagg_lr (estimators=100,
                              samples= 0.7, 
                              features= 1)

model_bagg.fit(x_train_over, y_train_over)
# Out:
# BaggingClassifier(estimator=LogisticRegression(max_iter=1000), max_features=1,
#                   max_samples=0.7, n_estimators=100, random_state=42)

# %%
# Function to obtain the performance metrics with the testing and training base:

def performances (model, x_train, y_train, x_test, y_test, threshold):  

    if isinstance(model, tf.keras.Model):
        y_pred_train = (model.predict(x_train) > threshold).astype("int32")
        y_proba_train = model.predict(x_train)[:,0]
        
    else:
        try:
            y_proba_train = model.predict_proba(x_train)[:,1]
            y_pred_train = np.where(y_proba_train > threshold, 1, 0)
            
        except Exception as e:
            print(f'Model not supported: {e}')
            return None
   
    acc_train = accuracy_score(y_train, y_pred_train).round(decimals=2)
    roc_train = roc_auc_score(y_train, y_proba_train).round(decimals=2)
    recl_train = recall_score(y_train, y_pred_train).round(decimals=2)

    df_train = x_train.copy()
    df_train['Default'] = y_train
    df_train['Prob(Y=1)'] = y_proba_train
    
    train_prob_y_real_0 = df_train.loc[df_train.Default==0,"Prob(Y=1)"]
    train_prob_y_real_1 = df_train.loc[df_train.Default==1,"Prob(Y=1)"]

    KS_train = (stats.ks_2samp(train_prob_y_real_0, train_prob_y_real_1).statistic).round(decimals=2)

    if isinstance(model, tf.keras.Model):
       
        y_pred_test = (model.predict(x_test) > threshold).astype("int32")
        y_proba_test = model.predict(x_test)[:,0]
    
    else:
        try:   
            y_proba_test = model.predict_proba(x_test)[:,1]
            y_pred_test = np.where(y_proba_test > threshold, 1, 0)
            
        except Exception as e:
            print(f'Model not supported: {e}')
            return None
            
    acc_test = accuracy_score(y_test, y_pred_test).round(decimals=2)
    roc_test = roc_auc_score(y_test, y_proba_test).round(decimals=2)
    recl_test = recall_score(y_test, y_pred_test).round(decimals=2)

    df_test = x_test.copy()
    df_test['Default'] = y_test
    df_test['Prob(Y=1)'] = y_proba_test
    
    test_prob_y_real_0 = df_test.loc[df_test.Default==0,"Prob(Y=1)"]
    test_prob_y_real_1 = df_test.loc[df_test.Default==1,"Prob(Y=1)"]   
    
    KS_test = (stats.ks_2samp(test_prob_y_real_0, test_prob_y_real_1).statistic).round(decimals=2)

                  
    df_performance = pd.DataFrame({'Train':[recl_train, roc_train, KS_train, acc_train],
                              'Test':[recl_test, roc_test, KS_test, acc_test]},
                            index=['Recall','AUROC','KS','Accuracy'])
    
    df_performance['Variation'] = round(df_performance['Test'] / df_performance['Train'] - 1, 2)

    return df_performance

# %%
# Obtaining the performances:

per_bagg = performances (model_bagg, x_train_over, y_train_over, X_test, y_test, 0.50) 
per_bagg
# Out:
#           Train  Test  Variation
# Recall     0.67  0.65      -0.03
# AUROC      0.72  0.71      -0.01
# KS         0.34  0.31      -0.09
# Accuracy   0.67  0.66      -0.01

# %%
# Random Forest model:

# %%
def train_RF (estimators, min_leaf, max_dp): 
    
    model_rf = RandomForestClassifier(n_estimators= estimators,               
                                   min_samples_leaf= min_leaf, 
                                   max_depth= max_dp,
                                   random_state = 42)
    return model_rf

# %%
# Definition of the hyperparametric space:

est = np.arange(50, 210, 50)

minlf = np.arange(10, 1500, 500)

maxdp = np.arange(3, 15, 1) 

param_grid = dict(estimators=est,
                  min_leaf= minlf,
                  max_dp = maxdp)

# %%
bo_space3 = {'estimators': hp.choice('estimators', param_grid['estimators']),
            'min_leaf': hp.choice('min_leaf', param_grid['min_leaf']),
            'max_dp': hp.choice('max_dp', param_grid['max_dp'])}

# %%
def bo_randomfor(param):   

    print ('tested_hyperparameters: ', param)
    model_bo = train_RF(estimators=param['estimators'], 
                                    min_leaf =param['min_leaf'],   
                                    max_dp=param['max_dp'])   
    
    model_bo.fit(x_train_over, y_train_over)    
      
    ypred_train = model_bo.predict(x_train_over)
    
    ypred_valid = model_bo.predict(x_valid)
    
    Prec_train = precision_score(y_train_over, ypred_train)    
    Prec_valid = precision_score(y_valid, ypred_valid)    
    Prec_Diference = (Prec_train - Prec_valid)/Prec_train
        
    Recl_train = recall_score(y_train_over, ypred_train)    
    Recl_valid = recall_score(y_valid, ypred_valid)    
    Recl_Diference = (Recl_train - Recl_valid)/Recl_train
    
    D_p = math.sqrt((Prec_valid - 1)**2 + (Prec_Diference - 0)**2)
    D_r = math.sqrt((Recl_valid - 1)**2 + (Recl_Diference - 0)**2)
    D_t = D_p + D_r
    
    print('Recl_valid :', Recl_valid, 'Recl_train :', Recl_train,
         'Prec_valid :', Prec_valid, 'Prec_train :',Prec_train)
    
    return {'loss': D_t,'status': STATUS_OK}

# %%
trials = Trials()                  
bo_search3 = fmin(fn= bo_randomfor,       
                 space= bo_space3,  
                 algo=tpe.suggest, 
                 max_evals=20,     
                 trials=trials)
# Out:
# tested_hyperparameters:
# {'estimators': 200, 'max_dp': 8, 'min_leaf': 10}
# Recl_valid :
# 0.6694055099081682
# Recl_train :
# 0.7623096071895701
# Prec_valid :
# 0.20303452319870996
# Prec_train :
# 0.6935168125287886
# tested_hyperparameters:
# {'estimators': 150, 'max_dp': 8, 'min_leaf': 1010}
# Recl_valid :
# 0.6418559690671822
# Recl_train :
# 0.7214252563182988
# Prec_valid :
# 0.2064676616915423
# Prec_train :
# 0.6910020408575643
# tested_hyperparameters:
# {'estimators': 150, 'max_dp': 12, 'min_leaf': 510}
# Recl_valid :
# 0.6488641855969067
# Recl_train :
# 0.730897430488165
# Prec_valid :
# 0.20703215359703908
# Prec_train :
# 0.6936413870425242
# tested_hyperparameters:
# {'estimators': 200, 'max_dp': 10, 'min_leaf': 10}
# Recl_valid :
# 0.6585306911551474
# Recl_train :
# 0.7725412429855281
# Prec_valid :
# 0.2041810280233778
# Prec_train :
# 0.7088931046498123
# tested_hyperparameters:
# {'estimators': 100, 'max_dp': 4, 'min_leaf': 510}
# Recl_valid :
# 0.6457225712904785
# Recl_train :
# 0.7317623728956584
# Prec_valid :
# 0.1968469132164432
# Prec_train :
# 0.6793912566593544
# tested_hyperparameters:
# {'estimators': 200, 'max_dp': 7, 'min_leaf': 1010}
# Recl_valid :
# 0.6445142580956984
# Recl_train :
# 0.7249483144171132
# Prec_valid :
# 0.20504343814868917
# Prec_train :
# 0.6893757021344888
# tested_hyperparameters:
# {'estimators': 150, 'max_dp': 10, 'min_leaf': 510}
# Recl_valid :
# 0.6466892218463025
# Recl_train :
# 0.7316568921142568
# Prec_valid :
# 0.2061633281972265
# Prec_train :
# 0.6933487935067272
# tested_hyperparameters:
# {'estimators': 200, 'max_dp': 6, 'min_leaf': 510}
# Recl_valid :
# 0.6597390043499275
# Recl_train :
# 0.7396312391882199
# Prec_valid :
# 0.2028985507246377
# Prec_train :
# 0.6852742269653258
# tested_hyperparameters:
# {'estimators': 50, 'max_dp': 12, 'min_leaf': 10}
# Recl_valid :
# 0.6476558724021266
# Recl_train :
# 0.7917387452006245
# Prec_valid :
# 0.20273848248732884
# Prec_train :
# 0.7284691084842485
# tested_hyperparameters:
# {'estimators': 150, 'max_dp': 3, 'min_leaf': 10}
# Recl_valid :
# 0.6377477042049299
# Recl_train :
# 0.720982237036412
# Prec_valid :
# 0.19548148148148148
# Prec_train :
# 0.6765515193506879
# tested_hyperparameters:
# {'estimators': 100, 'max_dp': 14, 'min_leaf': 510}
# Recl_valid :
# 0.6488641855969067
# Recl_train :
# 0.7298215265178685
# Prec_valid :
# 0.2068567026194145
# Prec_train :
# 0.6933004669432253
# tested_hyperparameters:
# {'estimators': 100, 'max_dp': 8, 'min_leaf': 1010}
# Recl_valid :
# 0.6423392943450943
# Recl_train :
# 0.7215940255685415
# Prec_valid :
# 0.20657495919794824
# Prec_train :
# 0.6911357620577478
# tested_hyperparameters:
# {'estimators': 50, 'max_dp': 12, 'min_leaf': 10}
# Recl_valid :
# 0.6476558724021266
# Recl_train :
# 0.7917387452006245
# Prec_valid :
# 0.20273848248732884
# Prec_train :
# 0.7284691084842485
# tested_hyperparameters:
# {'estimators': 50, 'max_dp': 8, 'min_leaf': 10}
# Recl_valid :
# 0.6662638956017399
# Recl_train :
# 0.7603687608117801
# Prec_valid :
# 0.20288468614320407
# Prec_train :
# 0.6940956709289786
# tested_hyperparameters:
# {'estimators': 50, 'max_dp': 12, 'min_leaf': 10}
# Recl_valid :
# 0.6476558724021266
# Recl_train :
# 0.7917387452006245
# Prec_valid :
# 0.20273848248732884
# Prec_train :
# 0.7284691084842485
# tested_hyperparameters:
# {'estimators': 150, 'max_dp': 11, 'min_leaf': 510}
# Recl_valid :
# 0.6498308361527307
# Recl_train :
# 0.731087295894688
# Prec_valid :
# 0.20668716372021523
# Prec_train :
# 0.6932802528657451
# tested_hyperparameters:
# {'estimators': 100, 'max_dp': 6, 'min_leaf': 510}
# Recl_valid :
# 0.6546640889318511
# Recl_train :
# 0.7379435466857939
# Prec_valid :
# 0.2015774983257683
# Prec_train :
# 0.6846339028829781
# tested_hyperparameters:
# {'estimators': 50, 'max_dp': 6, 'min_leaf': 1010}
# Recl_valid :
# 0.652005799903335
# Recl_train :
# 0.7313826420826125
# Prec_valid :
# 0.20302505831891038
# Prec_train :
# 0.686324583283842
# tested_hyperparameters:
# {'estimators': 100, 'max_dp': 3, 'min_leaf': 510}
# Recl_valid :
# 0.638714354760754
# Recl_train :
# 0.7201594869414792
# Prec_valid :
# 0.19554601953240602
# Prec_train :
# 0.6761006912122952
# tested_hyperparameters:
# {'estimators': 200, 'max_dp': 11, 'min_leaf': 510}
# Recl_valid :
# 0.6505558240695989
# Recl_train :
# 0.731804565208219
# Prec_valid :
# 0.20667946257197697
# Prec_train :
# 0.6928100659077292
# 100%|████████████████████████████████████████████████| 20/20 [12:21<00:00, 37.07s/trial, best loss: 1.4178667781930698]

# %%
# Obtaining the best hyperparameters:

bo_better_hp3 = space_eval(bo_space3, bo_search3)
print('Better hyperparameters: ', bo_better_hp3)
# Out:
# Better hyperparameters:  {'estimators': 200, 'max_dp': 8, 'min_leaf': 10}

# %%
# Fitting the chosen models (best hyperparameters):

model_randomfor =  train_RF (200, 10, 8)

model_randomfor.fit(x_train_over, y_train_over)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=10, n_estimators=200,
#                        random_state=42)

# %%
# Obtaining the performances:

per_rand = performances (model_randomfor, x_train_over, y_train_over, X_test, y_test, 0.50) 
per_rand
# Out:
#           Train  Test  Variation
# Recall     0.76  0.68      -0.11
# AUROC      0.79  0.73      -0.08
# KS         0.43  0.33      -0.23
# Accuracy   0.71  0.66      -0.07

# %%
# Artificial Neural Networks:

# %%
# Standardizing the scale of variables:

x_scaler = StandardScaler()

x_scaler.fit(x_train_over)
x_train_sc = x_scaler.transform(x_train_over)   
x_valid_sc = x_scaler.transform(x_valid)
x_test_sc = x_scaler.transform(X_test)

# %%
x_train_sc.shape[1]
# Out:
# 5

# %%
# Building Tensorflow model encapsulated as Scikit-Learn:

def model_ANN (num_layers=1, num_neurons=8, fn_activ_hl='tanh', drop = 0.1):
    
    model = keras.Sequential()
    
    # First hidden layer:
    model.add(layers.Dense(num_neurons, 
                           activation=str(fn_activ_hl),
                           kernel_regularizer=keras.regularizers.l1_l2(),
                           input_shape=(x_train_sc.shape[1],)))
    model.add(layers.Dropout(drop))
    
    # Add more hidden layers:
    if num_layers > 1:
        for i in np.arange(2, num_layers, 1):
            model.add(layers.Dense(num_neurons, 
                                   activation=str(fn_activ_hl),
                                   kernel_regularizer=keras.regularizers.l1_l2()))
            model.add(layers.Dropout(drop))
    
    # Output layer:
    model.add(layers.Dense(1, activation='sigmoid'))
     
   
    model.compile(loss='binary_crossentropy', 
                  optimizer=keras.optimizers.Adam(),
                  metrics= [tf.keras.metrics.Recall(name='recl')])
    return model

# %%
# Definition of hyperparametric space:

ehp_layers = np.arange(2, 6, 1)

ehp_neurons = np.power(2, np.arange(3, 6, 1))

ehp_fnactiv_hl = ['relu','tanh','linear']

drop = np.arange(0, 0.15, 0.05).round(decimals=2)

param_grid = dict(num_layers=ehp_layers,
                  num_neurons=ehp_neurons,
                  fn_activ_hl=ehp_fnactiv_hl,
                  drop = drop)

# %%
bo_space4 = {'num_layers': hp.choice('num_layers', param_grid['num_layers']),
            'num_neurons': hp.choice('num_neurons', param_grid['num_neurons']),
            'fn_activ_hl': hp.choice('fn_activ_hl', param_grid['fn_activ_hl']),
             'drop': hp.choice('drop', param_grid['drop'])}

# %%
# Defining the function that will be optimized:

# %%
# Early Stopping (callbacks):

rna_es = keras.callbacks.EarlyStopping(
monitor="val_recl",    
min_delta=0.005,
patience = 20,
verbose=1,
mode='max',
restore_best_weights=True)

# %%
def bo_naa(param):   

    print ('Hiperparametros testados: ', param)
    model = model_ANN (num_layers=param['num_layers'], 
                          num_neurons=param['num_neurons'],
                          fn_activ_hl=param['fn_activ_hl'],
                            drop = param['drop']) 

    model.fit(x_train_sc, 
            y_train_over,
            epochs=100,        
            batch_size=32,       
            validation_split= 0.2,  
            callbacks=[rna_es],        
            verbose=0) 

    ypred_train = (model.predict(x_train_sc) > 0.5).astype("int32") 
        
    ypred_valid = (model.predict(x_valid_sc) > 0.5).astype("int32")
                                                                 
    Prec_train = precision_score(y_train_over, ypred_train)    
    Prec_valid = precision_score(y_valid, ypred_valid)    
    Prec_Diference = (Prec_train - Prec_valid)/Prec_train
        
    Recl_train = recall_score(y_train_over, ypred_train)    
    Recl_valid = recall_score(y_valid, ypred_valid)    
    Recl_Diference = (Recl_train - Recl_valid)/Recl_train
    
    D_p = math.sqrt((Prec_valid - 1)**2 + (Prec_Diference - 0)**2)
    D_r = math.sqrt((Recl_valid - 1)**2 + (Recl_Diference - 0)**2)
    D_t = D_p + D_r
    
    print('Recl_valid :', Recl_valid, 'Recl_train :', Recl_train,
         'Prec_valid :', Prec_valid, 'Prec_train :',Prec_train)
    
    return {'loss': D_t,'status': STATUS_OK}

# %%
trials = Trials()                  
bo_search4 = fmin(fn= bo_naa,       
                 space= bo_space4,  
                 algo=tpe.suggest, 
                 max_evals=20,    
                 trials=trials)
# Out:
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'relu', 'num_layers': 4, 'num_neurons': 16}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.0
# Recl_train :
# 0.0
# Prec_valid :
# 0.0
# Prec_train :
# 0.0
# Hiperparametros testados:
# {'drop': 0.0, 'fn_activ_hl': 'relu', 'num_layers': 2, 'num_neurons': 8}
#   5%|███▏                                                            | 1/20 [01:35<30:20, 95.79s/trial, best loss: nan]
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Prec_Diference = (Prec_train - Prec_valid)/Prec_train
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   Recl_Diference = (Recl_train - Recl_valid)/Recl_train
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# Recl_valid :
# 0.5106331561140648
# Recl_train :
# 0.5189654444960128
# Prec_valid :
# 0.2535397168226542
# Prec_train :
# 0.7250007367893666
# Hiperparametros testados:
# {'drop': 0.0, 'fn_activ_hl': 'relu', 'num_layers': 3, 'num_neurons': 16}
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# Recl_valid :
# 0.5642822619623006
# Recl_train :
# 0.5788785283321379
# Prec_valid :
# 0.23715214300223442
# Prec_train :
# 0.7102552156131905
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'relu', 'num_layers': 4, 'num_neurons': 32}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.0
# Recl_train :
# 0.0
# Prec_valid :
# 0.0
# Prec_train :
# 0.0
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'relu', 'num_layers': 3, 'num_neurons': 8}
#  20%|████████████▌                                                  | 4/20 [08:01<31:27, 117.96s/trial, best loss: nan]
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Prec_Diference = (Prec_train - Prec_valid)/Prec_train
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   Recl_Diference = (Recl_train - Recl_valid)/Recl_train
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# Recl_valid :
# 0.5328661188980184
# Recl_train :
# 0.5435002742500317
# Prec_valid :
# 0.24639624539054644
# Prec_train :
# 0.7186331938633194
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'relu', 'num_layers': 4, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.0
# Recl_train :
# 0.0
# Prec_valid :
# 0.0
# Prec_train :
# 0.0
# Hiperparametros testados:
# {'drop': 0.05, 'fn_activ_hl': 'relu', 'num_layers': 2, 'num_neurons': 8}
#  30%|██████████████████▉                                            | 6/20 [11:43<25:53, 110.94s/trial, best loss: nan]
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Prec_Diference = (Prec_train - Prec_valid)/Prec_train
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   Recl_Diference = (Recl_train - Recl_valid)/Recl_train
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# Recl_valid :
# 0.5260995650072499
# Recl_train :
# 0.5615163917134298
# Prec_valid :
# 0.2503162009888467
# Prec_train :
# 0.7332304895181951
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'tanh', 'num_layers': 2, 'num_neurons': 32}
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
# Recl_valid :
# 0.5053165780570323
# Recl_train :
# 0.5136703092696511
# Prec_valid :
# 0.25171542072950526
# Prec_train :
# 0.72575260804769
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'tanh', 'num_layers': 3, 'num_neurons': 16}
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
# Recl_valid :
# 0.5212663122281296
# Recl_train :
# 0.5307792920129952
# Prec_valid :
# 0.2496816761199213
# Prec_train :
# 0.722448745190375
# Hiperparametros testados:
# {'drop': 0.05, 'fn_activ_hl': 'relu', 'num_layers': 3, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# Recl_valid :
# 0.5432576123731271
# Recl_train :
# 0.5594911607105185
# Prec_valid :
# 0.2394291191820215
# Prec_train :
# 0.7127768221887766
# Hiperparametros testados:
# {'drop': 0.0, 'fn_activ_hl': 'tanh', 'num_layers': 3, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# Recl_valid :
# 0.5176413726437893
# Recl_train :
# 0.5246403105354205
# Prec_valid :
# 0.2517926413541789
# Prec_train :
# 0.7237776484284051
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'relu', 'num_layers': 2, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.44562590623489606
# Recl_train :
# 0.4515210328678115
# Prec_valid :
# 0.2701039988281822
# Prec_train :
# 0.7418460365325292
# Hiperparametros testados:
# {'drop': 0.1, 'fn_activ_hl': 'relu', 'num_layers': 4, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# Recl_valid :
# 0.3765103914934751
# Recl_train :
# 0.37004767731319355
# Prec_valid :
# 0.29852462157501436
# Prec_train :
# 0.7652139772281115
# Hiperparametros testados:
# {'drop': 0.1, 'fn_activ_hl': 'tanh', 'num_layers': 5, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.0
# Recl_train :
# 0.0
# Prec_valid :
# 0.0
# Prec_train :
# 0.0
# Hiperparametros testados:
# {'drop': 0.05, 'fn_activ_hl': 'relu', 'num_layers': 2, 'num_neurons': 16}
#  70%|████████████████████████████████████████████                   | 14/20 [26:01<09:52, 98.78s/trial, best loss: nan]
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Prec_Diference = (Prec_train - Prec_valid)/Prec_train
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   Recl_Diference = (Recl_train - Recl_valid)/Recl_train
# Restoring model weights from the end of the best epoch.
# Epoch 00029: early stopping
# Recl_valid :
# 0.5176413726437893
# Recl_train :
# 0.5348297540188178
# Prec_valid :
# 0.25692695214105793
# Prec_train :
# 0.7338408544880887
# Hiperparametros testados:
# {'drop': 0.0, 'fn_activ_hl': 'relu', 'num_layers': 4, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00026: early stopping
# Recl_valid :
# 0.5026582890285162
# Recl_train :
# 0.5109700012657694
# Prec_valid :
# 0.2545276554087127
# Prec_train :
# 0.7276851434580142
# Hiperparametros testados:
# {'drop': 0.05, 'fn_activ_hl': 'tanh', 'num_layers': 3, 'num_neurons': 8}
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# Recl_valid :
# 0.5239246012566457
# Recl_train :
# 0.532192734483777
# Prec_valid :
# 0.24802654158563092
# Prec_train :
# 0.7205038128695056
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'tanh', 'num_layers': 4, 'num_neurons': 32}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.0
# Recl_train :
# 0.0
# Prec_valid :
# 0.0
# Prec_train :
# 0.0
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'tanh', 'num_layers': 3, 'num_neurons': 8}
#  90%|███████████████████████████████████████████████████████▊      | 18/20 [33:19<03:36, 108.01s/trial, best loss: nan]
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Prec_Diference = (Prec_train - Prec_valid)/Prec_train
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   Recl_Diference = (Recl_train - Recl_valid)/Recl_train
# Restoring model weights from the end of the best epoch.
# Epoch 00028: early stopping
# Recl_valid :
# 0.49951667472208794
# Recl_train :
# 0.5093455972321843
# Prec_valid :
# 0.25321572951120913
# Prec_train :
# 0.7257642708990892
# Hiperparametros testados:
# {'drop': 0.15, 'fn_activ_hl': 'relu', 'num_layers': 5, 'num_neurons': 16}
# Restoring model weights from the end of the best epoch.
# Epoch 00021: early stopping
# Recl_valid :
# 0.0
# Recl_train :
# 0.0
# Prec_valid :
# 0.0
# Prec_train :
# 0.0
# 100%|██████████████████████████████████████████████████████████████| 20/20 [36:20<00:00, 109.03s/trial, best loss: nan]
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# c:\users\kaka_\preditiva\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   Prec_Diference = (Prec_train - Prec_valid)/Prec_train
#
# C:\Users\kaka_\AppData\Local\Temp\ipykernel_26308\1966972366.py:37: RuntimeWarning: invalid value encountered in double_scalars
#   Recl_Diference = (Recl_train - Recl_valid)/Recl_train

# %%
# Obtaining the best hyperparameters:

bo_better_hp4 = space_eval(bo_space4, bo_search4)
print('Better hyperparameters: ', bo_better_hp4)
# Out:
# Better hyperparameters:  {'drop': 0.0, 'fn_activ_hl': 'relu', 'num_layers': 3, 'num_neurons': 16}

# %%
# Fitting the chosen models (best hyperparameters):

model_ann = model_ANN(num_layers = 3,
                      num_neurons= 16,
                      fn_activ_hl= 'relu',
                         drop=0)

model_ann.fit(x_train_sc, 
            y_train_over,
            epochs=100,
            batch_size=32,
            validation_split=0.2,
            callbacks=rna_es,
            verbose=1)
# Out:
# Epoch 1/100
# 2371/2371 [==============================] - 5s 2ms/step - loss: 0.9310 - recl: 0.0902 - val_loss: 0.8840 - val_recl: 0.4250
# Epoch 2/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.6067 - recl: 0.4354 - val_loss: 0.8096 - val_recl: 0.4815
# Epoch 3/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.6027 - recl: 0.4412 - val_loss: 0.8251 - val_recl: 0.4713
# Epoch 4/100
# 2371/2371 [==============================] - 4s 1ms/step - loss: 0.5967 - recl: 0.4540 - val_loss: 0.8402 - val_recl: 0.4494
# Epoch 5/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5938 - recl: 0.4477 - val_loss: 0.8251 - val_recl: 0.4652
# Epoch 6/100
# 2371/2371 [==============================] - 4s 1ms/step - loss: 0.5939 - recl: 0.4535 - val_loss: 0.8093 - val_recl: 0.4830
# Epoch 7/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5947 - recl: 0.4486 - val_loss: 0.8738 - val_recl: 0.4205
# Epoch 8/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5902 - recl: 0.4588 - val_loss: 0.8171 - val_recl: 0.4614
# Epoch 9/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5910 - recl: 0.4566 - val_loss: 0.7760 - val_recl: 0.5187
# Epoch 10/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5939 - recl: 0.4583 - val_loss: 0.8671 - val_recl: 0.4309
# Epoch 11/100
# 2371/2371 [==============================] - 3s 1ms/step - loss: 0.5918 - recl: 0.4626 - val_loss: 0.8271 - val_recl: 0.4407
# Epoch 12/100
# 2371/2371 [==============================] - 3s 1ms/step - loss: 0.5918 - recl: 0.4551 - val_loss: 0.8735 - val_recl: 0.4122
# Epoch 13/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5897 - recl: 0.4649 - val_loss: 0.7975 - val_recl: 0.4835
# Epoch 14/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5903 - recl: 0.4677 - val_loss: 0.7976 - val_recl: 0.4949
# Epoch 15/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5898 - recl: 0.4601 - val_loss: 0.8837 - val_recl: 0.4222
# Epoch 16/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5906 - recl: 0.4644 - val_loss: 0.8098 - val_recl: 0.4755
# Epoch 17/100
# 2371/2371 [==============================] - 4s 1ms/step - loss: 0.5897 - recl: 0.4634 - val_loss: 0.8413 - val_recl: 0.4493
# Epoch 18/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5903 - recl: 0.4610 - val_loss: 0.7856 - val_recl: 0.4988
# Epoch 19/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5879 - recl: 0.4652 - val_loss: 0.8456 - val_recl: 0.4374
# Epoch 20/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5913 - recl: 0.4632 - val_loss: 0.8303 - val_recl: 0.4531
# Epoch 21/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5874 - recl: 0.4656 - val_loss: 0.8398 - val_recl: 0.4522
# Epoch 22/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5870 - recl: 0.4614 - val_loss: 0.7960 - val_recl: 0.4849
# Epoch 23/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5886 - recl: 0.4630 - val_loss: 0.8706 - val_recl: 0.4173
# Epoch 24/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5888 - recl: 0.4685 - val_loss: 0.8550 - val_recl: 0.4339
# Epoch 25/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5878 - recl: 0.4610 - val_loss: 0.7830 - val_recl: 0.5064
# Epoch 26/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5874 - recl: 0.4712 - val_loss: 0.8331 - val_recl: 0.4618
# Epoch 27/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5889 - recl: 0.4685 - val_loss: 0.8606 - val_recl: 0.4388
# Epoch 28/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5853 - recl: 0.4634 - val_loss: 0.7472 - val_recl: 0.5344
# Epoch 29/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5867 - recl: 0.4563 - val_loss: 0.8244 - val_recl: 0.4662
# Epoch 30/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5874 - recl: 0.4565 - val_loss: 0.8355 - val_recl: 0.4555
# Epoch 31/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5864 - recl: 0.4666 - val_loss: 0.7412 - val_recl: 0.5456
# Epoch 32/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5889 - recl: 0.4616 - val_loss: 0.8279 - val_recl: 0.4714
# Epoch 33/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5841 - recl: 0.4660 - val_loss: 0.8873 - val_recl: 0.4056
# Epoch 34/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5854 - recl: 0.4617 - val_loss: 0.8629 - val_recl: 0.4354
# Epoch 35/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5870 - recl: 0.4641 - val_loss: 0.8378 - val_recl: 0.4484
# Epoch 36/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5827 - recl: 0.4647 - val_loss: 0.8131 - val_recl: 0.4703
# Epoch 37/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5876 - recl: 0.4649 - val_loss: 0.8475 - val_recl: 0.4371
# Epoch 38/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5826 - recl: 0.4669 - val_loss: 0.7727 - val_recl: 0.5063
# Epoch 39/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5871 - recl: 0.4635 - val_loss: 0.7964 - val_recl: 0.4873
# Epoch 40/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5867 - recl: 0.4659 - val_loss: 0.7937 - val_recl: 0.5043
# Epoch 41/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5860 - recl: 0.4732 - val_loss: 0.8339 - val_recl: 0.4408
# Epoch 42/100
# 2371/2371 [==============================] - 3s 1ms/step - loss: 0.5835 - recl: 0.4761 - val_loss: 0.8793 - val_recl: 0.4096
# Epoch 43/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5867 - recl: 0.4644 - val_loss: 0.8735 - val_recl: 0.4118
# Epoch 44/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5852 - recl: 0.4661 - val_loss: 0.7859 - val_recl: 0.4994
# Epoch 45/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5844 - recl: 0.4729 - val_loss: 0.8167 - val_recl: 0.4682
# Epoch 46/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5871 - recl: 0.4755 - val_loss: 0.8107 - val_recl: 0.4912
# Epoch 47/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5856 - recl: 0.4694 - val_loss: 0.8304 - val_recl: 0.4569
# Epoch 48/100
# 2371/2371 [==============================] - 3s 1ms/step - loss: 0.5863 - recl: 0.4694 - val_loss: 0.7878 - val_recl: 0.5056
# Epoch 49/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5869 - recl: 0.4653 - val_loss: 0.7743 - val_recl: 0.5089
# Epoch 50/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5858 - recl: 0.4569 - val_loss: 0.8060 - val_recl: 0.4876
# Epoch 51/100
# 2371/2371 [==============================] - 4s 2ms/step - loss: 0.5841 - recl: 0.4659 - val_loss: 0.8407 - val_recl: 0.4399
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping

# %%
x_train_2 = pd.DataFrame(x_train_sc, columns = x_feat_name)
x_test_2 = pd.DataFrame(x_test_sc, columns = x_feat_name)

# %%
per_ann = performances (model_ann, x_train_2, y_train_over, x_test_2, y_test, 0.5)
per_ann
# Out:
#           Train  Test  Variation
# Recall     0.54  0.54       0.00
# AUROC      0.75  0.74      -0.01
# KS         0.37  0.02      -0.95
# Accuracy   0.67  0.76       0.13

# %%
# Putting the results into a dataframe:

# %%
Recall_Test = []
AUROC_Test = []
KS_Test = []
Accur_Test = []
Recall_Var = []
AUROC_Var = []
KS_Var = []
Accur_Var = []

models = [per_gbc_1, per_bagg_1, per_rand_1, per_ann_1, per_gbc_2, per_bagg_2, per_rand_2, per_ann_2,
          perf_gbc_3, per_bagg_3, per_rand_3, per_ann_3, per_gbc_4, per_bagg_4, per_rand_4, per_ann_4]

for i in np.arange(0, 4):
    for model in models:
        
        result_1 = model['Test'][i]
    
        result_2 = model['Variation'][i]

        if i == 0:
            Recall_Test.append(result_1)  
            Recall_Var.append(result_2)             
        if i == 1:
            AUROC_Test.append(result_1)  
            AUROC_Var.append(result_2) 
        if i == 2:
            KS_Test.append(result_1)  
            KS_Var.append(result_2)             
        if i == 3:
            Accur_Test.append(result_1)  
            Accur_Var.append(result_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 10>()
#       7 KS_Var = []
#       8 Accur_Var = []
# ---> 10 models = [per_gbc_1, per_bagg_1, per_rand_1, per_ann_1, per_gbc_2, per_bagg_2, per_rand_2, per_ann_2,
#      11           perf_gbc_3, per_bagg_3, per_rand_3, per_ann_3, per_gbc_4, per_bagg_4, per_rand_4, per_ann_4]
#      13 for i in np.arange(0, 4):
#      14     for model in models:
#
# NameError: name 'per_gbc_1' is not defined

# %%
models = ['Grad_1', 'Bagg_1', 'Rand_1', 'ANN_1', 'Grad_2', 'Bagg_2', 'Rand_2', 'ANN_2'
          'Grad_3', 'Bagg_3', 'Rand_3', 'ANN_3', 'Grad_4', 'Bagg_4', 'Rand_4', 'ANN_4']

resume = pd.DataFrame({'Recall_Test': Recall_Test,'Recall_Var': Recall_Var,
                       'AUROC_Test': AUROC_Test ,'AUROC_Var': AUROC_Var,
                       'KS_Test': KS_Test,'KS_Var': KS_Var,
                       'Accur_Test': Accur_Test,'Accur_Var': Accur_Var}, index = models)

# %%
Recall_Test = per_gbc['Test'][0], per_bagg['Test'][0], per_rand['Test'][0], per_ann['Test'][0]
AUROC_Test = per_gbc['Test'][1], per_bagg['Test'][1], per_rand['Test'][1], per_ann['Test'][1]
KS_Test = per_gbc['Test'][2], per_bagg['Test'][2], per_rand['Test'][2], per_ann['Test'][2]
Accur_Test = per_gbc['Test'][3], per_bagg['Test'][3], per_rand['Test'][3], per_ann['Test'][3]
Recall_Var = per_gbc['Variation'][0], per_bagg['Variation'][0], per_rand['Variation'][0], per_ann['Variation'][0]
AUROC_Var = per_gbc['Variation'][1], per_bagg['Variation'][1], per_rand['Variation'][1], per_ann['Variation'][1]
KS_Var = per_gbc['Variation'][2], per_bagg['Variation'][2], per_rand['Variation'][2], per_ann['Variation'][2]
Accur_Var = per_gbc['Variation'][3], per_bagg['Variation'][3], per_rand['Variation'][3], per_ann['Variation'][3]

index = ['Gradient_Boost', 'Logist_Regres', 'Random_For','Art_Neural_Net']

# %%
resume = pd.DataFrame({'Recall_Test': Recall_Test,'Recall_Var': Recall_Var,
                       'AUROC_Test': AUROC_Test ,'AUROC_Var': AUROC_Var,
                       'KS_Test': KS_Test,'KS_Var': KS_Var,
                       'Accur_Test': Accur_Test,'Accur_Var': Accur_Var}, index = index)

# %%
resume.sort_values(by=['Recall_Test','Recall_Var','AUROC_Test', 'AUROC_Var','KS_Test', 'KS_Var'],
                   ascending=[False, False, False, False,False, False])
# Out:
#                 Recall_Test  Recall_Var  AUROC_Test  AUROC_Var  KS_Test  \
# Random_For             0.68       -0.11        0.73      -0.08     0.33
# Logist_Regres          0.65       -0.03        0.71      -0.01     0.31
# Gradient_Boost         0.65       -0.12        0.72      -0.08     0.32
# Art_Neural_Net         0.54        0.00        0.74      -0.01     0.02
#
#                 KS_Var  Accur_Test  Accur_Var
# Random_For       -0.23        0.66      -0.07
# Logist_Regres    -0.09        0.66      -0.01
# Gradient_Boost   -0.24        0.67      -0.06
# Art_Neural_Net   -0.95        0.76       0.13

# %%
# Sobre os hiperparãmetros do GradientBoosting:

# O argumento learning_rate na função GradientBoostingClassifier é um hiperparâmetro que controla a contribuição de cada árvore no modelo durante o treinamento.
# Em algoritmos de boosting, como o Gradient Boosting, várias árvores (estimadores) são treinadas sequencialmente, e cada árvore tenta corrigir os erros das árvores anteriores. 
# O learning_rate é um valor que multiplica a contribuição de cada árvore ao modelo. 
# Um valor mais baixo de learning_rate geralmente resulta em um modelo mais robusto, pois reduz a influência de cada árvore individual, tornando o treinamento mais lento, mas potencialmente mais preciso.
# Por outro lado, um learning_rate mais alto pode levar a um treinamento mais rápido, mas também pode tornar o modelo mais propenso a overfitting, especialmente se o número de árvores (n_estimators) for alto.
# Em resumo, o learning_rate é um parâmetro de ajuste fino que equilibra a contribuição de cada árvore no ensemble, afetando a taxa de aprendizado do modelo.
# Ao ajustar esse parâmetro, você pode controlar o equilíbrio entre a velocidade de treinamento e a precisão do modelo.

# O argumento subsample controla a fração dos exemplos de treinamento que são amostrados aleatoriamente e usados para ajustar cada árvore de decisão em um estágio específico do algoritmo de Gradient Boosting.

# %%
# Abaixo código para fazer tunning de hiperparâmetro usando K-Fold estratificado:

# %%
def bo_gpc(param, x_train, y_train, x_valid, y_valid):   

    print ('tested_hyperparameters: ', param)
    model_bo= train_oversm_boosting(estimators=param['estimators'], 
                                    lean_rate=param['lean_rate'],
                                    sample =param['sample'],
                                    max_dp=param['max_dp'])   
    
   
    Prec_train = []
    Prec_valid = []    
    Recl_train = []
    Recl_valid = []
    
    partitions = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 42) 
    
    for train_index, valid_index in partitions.split(x_train, y_train):
        
        xtrain_train, xtrain_valid = x_train.iloc[train_index], x_train.iloc[valid_index]
        ytrain_train, ytrain_valid = y_train.iloc[train_index], y_train.iloc[valid_index] 
        
        under_tomek = TomekLinks(sampling_strategy='majority',n_jobs=4)

        x_train_tomek, y_train_tomek = under_tomek.fit_resample(xtrain_train, ytrain_train)

        rnd_under = RandomUnderSampler(sampling_strategy=0.35,
                                        random_state=42)
        x_train_under, y_train_under = rnd_under.fit_resample(x_train_tomek, y_train_tomek)
        
        smote = SMOTE(sampling_strategy= 1, random_state=42)

        x_train_over, y_train_over = smote.fit_resample(x_train_under, y_train_under)
            
        model_bo.fit(x_train_over, y_train_over)    
        
        ypred_train = model_bo.predict(x_train_over)
        y_proba_train = model_bo.predict_proba(x_train_over)[:,1]
    
        ypred_valid = model_bo.predict(xtrain_valid)
        y_proba_valid = model_bo.predict_proba(xtrain_valid)[:,1]
        
        Recl_train.append(recall_score(y_train_over, ypred_train))
        Recl_valid.append(recall_score(ytrain_valid, ypred_valid))   
        
        Prec_train.append(precision_score(y_train_over, ypred_train))    
        Prec_valid.append(precision_score(ytrain_valid, ypred_valid))  
        
    Prec_train_mean = np.mean(Prec_train)
    Prec_valid_mean = np.mean(Prec_valid)
    Prec_Diference = (Prec_train_mean - Prec_valid_mean)/Prec_train_mean
   
    Recl_train_mean = np.mean(Recl_train)
    Recl_valid_mean = np.mean(Recl_valid)
    Recl_Diference = (Recl_train_mean - Recl_valid_mean)/Recl_train_mean
        
    D_p = math.sqrt((Prec_valid_mean - 1)**2 + (Prec_Diference - 0)**2)
    D_r = math.sqrt((Recl_valid_mean - 1)**2 + (Recl_Diference - 0)**2)
        
    D_t = D_p + D_r
        
    print('Prec_valid :', Prec_valid_mean, 'Diference_Prec :', Prec_Diference,
          'Recl_valid :', Recl_valid_mean, 'Diference_Recl :', Recl_Diference)
    
    return {'loss': D_t,'status': STATUS_OK}
